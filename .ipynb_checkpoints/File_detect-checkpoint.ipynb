# %%
import pathlib
from PIL import Image
file = pathlib.Path("./Test_folder")
list(file.iterdir())
# Out:
# [PosixPath('Test_folder/download.jpeg'),
#  PosixPath('Test_folder/.DS_Store'),
#  PosixPath('Test_folder/60eb8ad381234091b2481859ef8acb1e.jpeg')]

# %%
import imghdr
imghdr.what("Test_folder/60eb8ad381234091b2481859ef8acb1e.jpeg") == "jpeg"
# Out:
# True

# %%
for item in file.iterdir():
    if imghdr.what(item) == "jpeg" or imghdr.what(item) == "png":
        print(item)
# Out:
# Test_folder/download.jpeg
# Test_folder/download.png
# Test_folder/60eb8ad381234091b2481859ef8acb1e.jpeg

# %%
for item in list(file.iterdir()):
    if imghdr.what(item) == "jpeg" or imghdr.what(item) == "png":
        print(Image.open(str(item)))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=348x145 at 0x7FE206204AC0>
# <PIL.PngImagePlugin.PngImageFile image mode=P size=233x216 at 0x7FE206204AC0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1130 at 0x7FE20AA62DC0>

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(10, 7))
rows = 2
columns = 2

index = 1

for item in file.iterdir():
    if imghdr.what(item) == "jpeg" or imghdr.what(item) == "png":

        # Adds a subplot at the 1st position
        fig.add_subplot(rows, columns, index)
        # showing image
        plt.imshow(Image.open(item))
        plt.axis('off')
        index=index+1

# %%
pip install watchdog
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

class  MyHandler(FileSystemEventHandler):
    def  on_modified(self,  event):
         print(f'event type: {event.event_type} path : {event.src_path}')
    def  on_created(self,  event):
         print(f'event type: {event.event_type} path : {event.src_path}')
    def  on_deleted(self,  event):
         print(f'event type: {event.event_type} path : {event.src_path}')

if __name__ ==  "__main__":
    event_handler = MyHandler()
    observer = Observer()
    observer.schedule(event_handler,  path="./Test_folder",  recursive=False)
    observer.start()
    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        observer.stop()
    observer.join()
# Out:
# event type: modified path : /Users/bettywan/Desktop/CerebroProjects/File_detect/Test_folder/.DS_Store
# event type: deleted path : /Users/bettywan/Desktop/CerebroProjects/File_detect/Test_folder/60eb8ad381234091b2481859ef8acb1e copy.jpeg
# event type: modified path : /Users/bettywan/Desktop/CerebroProjects/File_detect/Test_folder
# event type: modified path : /Users/bettywan/Desktop/CerebroProjects/File_detect/Test_folder/.DS_Store
# event type: created path : /Users/bettywan/Desktop/CerebroProjects/File_detect/Test_folder/download copy.png
# event type: modified path : /Users/bettywan/Desktop/CerebroProjects/File_detect/Test_folder
# event type: modified path : /Users/bettywan/Desktop/CerebroProjects/File_detect/Test_folder/download copy.png
# event type: created path : /Users/bettywan/Desktop/CerebroProjects/File_detect/Test_folder/download copy 2.png
# event type: modified path : /Users/bettywan/Desktop/CerebroProjects/File_detect/Test_folder
# ...
